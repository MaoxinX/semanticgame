# %%
from csv_to_json.py import csv_to_json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from csv_to_json.py import csv_to_json
#
# ModuleNotFoundError: No module named 'csv_to_json.py'; 'csv_to_json' is not a package

# %%
csv_to_json('category_order_from_pilot.csv', 'category_order_from_pilot.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 csv_to_json('category_order_from_pilot.csv', 'category_order_from_pilot.json')
#
# NameError: name 'csv_to_json' is not defined
